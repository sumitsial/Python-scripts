# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('exp_behavior.csv')

# %%
sep= df.iloc[::4]

# %%
cost_per_tonne= df.iloc[1::4,:]

# %%
plt.figure(figsize=(10,5))
sns.set()
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=sep)
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='Waste separation (%)')
ax.set(ylim = (0,8))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne)
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,120))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df.iloc[2::4,:]
print (Energy)
# Out:
#          values   attri              run
# 2    279.194662  energy         Baseline
# 6    276.778828  energy         Baseline
# 10   276.705272  energy         Baseline
# 14   277.698092  energy         Baseline
# 18   277.682513  energy         Baseline
# ..          ...     ...              ...
# 822  296.348874  energy  Highly egoistic
# 826  295.526630  energy  Highly egoistic
# 830  295.340877  energy  Highly egoistic
# 834  295.259881  energy  Highly egoistic
# 838  294.619190  energy  Highly egoistic
#
# [210 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=Energy)
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (270,310))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df.iloc[3::4,:]
print (co2)
# Out:
#         values attri              run
# 3    79.763962   co2         Baseline
# 7    80.638422   co2         Baseline
# 11   80.521738   co2         Baseline
# 15   80.196449   co2         Baseline
# 19   80.132986   co2         Baseline
# ..         ...   ...              ...
# 823  85.381574   co2  Highly egoistic
# 827  84.989337   co2  Highly egoistic
# 831  84.916163   co2  Highly egoistic
# 835  85.073053   co2  Highly egoistic
# 839  84.885594   co2  Highly egoistic
#
# [210 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=co2)
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (70,100))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
df1 = pd.read_csv('exp_awareness.csv')

# %%
cost_per_tonne= df1.iloc[1::4,:]

# %%
plt.figure(figsize=(10,5))
#sns.palplot(sns.color_palette("Paired"))
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne,palette='Paired')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,116))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df1.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=Energy,palette='Paired')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (270,320))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df1.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=co2,palette='Paired')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (80,88))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
sep= df1.iloc[::4]

# %%
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=sep,palette='Paired')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='Waste separation (%)')
ax.set(ylim = (-1,7.5))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
df2 = pd.read_csv('exp_urban.csv')

# %%
cost_per_tonne= df2.iloc[1::4,:]
plt.figure(figsize=(12,7))
sns.set()
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne,palette='pastel')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,110))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df2.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=Energy,palette='pastel')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (270,282))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df2.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=co2,palette='pastel')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (78,82))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
sep= df2.iloc[::4]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=sep,palette='pastel')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='Waste separation (%)')
ax.set(ylim = (5,10))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
df3 = pd.read_csv('exp_wms.csv')

# %%
cost_per_tonne= df3.iloc[1::4,:]
plt.figure(figsize=(10,5))

ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne,palette='coolwarm')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,130))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df3.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='run' , hue= 'attri', data=Energy,palette='pastel')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (250,300))
ax.set_title(" ")
l = ax.legend()
ax.legend_.remove()  ## to remove legend
l.set_title(' ')

# %%
co2= df3.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=co2,palette='coolwarm')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (78,82.5))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
sep= df3.iloc[::4]

# %%
plt.figure(figsize=(10,5))
sns.set()
ax = sns.boxplot(y= 'values', x='run' , hue= 'attri', data=sep,palette='pastel')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='Waste separation (%)')
ax.set(ylim = (5,26))
ax.set_title(" ")
l = ax.legend()
ax.legend_.remove()  ## to remove legend
l.set_title(' ')

# %%
df4 = pd.read_csv('exp_meth2elec.csv')

# %%
cost_per_tonne= df4.iloc[1::4,:]
plt.figure(figsize=(10,5))
sns.set()
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne,palette ='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,110))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df4.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=Energy,palette ='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (250,300))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df4.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=co2,palette ='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (78,86))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
df5 = pd.read_csv('exp_bio2meth(electricity).csv')

# %%
cost_per_tonne= df5.iloc[1::4,:]
plt.figure(figsize=(10,5))

ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne,palette='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,110))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df5.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=Energy,palette='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (250,300))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df5.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=co2,palette='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (78,86))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
print (Energy)
# Out:
#          values   attri                              run
# 2    279.194662  energy  Biogas to electricity(Baseline)
# 6    276.778828  energy  Biogas to electricity(Baseline)
# 10   276.705272  energy  Biogas to electricity(Baseline)
# 14   277.698092  energy  Biogas to electricity(Baseline)
# 18   277.682513  energy  Biogas to electricity(Baseline)
# ..          ...     ...                              ...
# 342  262.667483  energy               Partial conversion
# 346  263.736799  energy               Partial conversion
# 350  265.067435  energy               Partial conversion
# 354  265.848256  energy               Partial conversion
# 358  265.891271  energy               Partial conversion
#
# [90 rows x 3 columns]

# %%
Energy.to_csv('out.csv', sep='\t')

# %%
df6 = pd.read_csv('exp_phase.csv')

# %%
cost_per_tonne= df6.iloc[1::4,:]
plt.figure(figsize=(10,5))

ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=cost_per_tonne,palette='Blues')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (106,109))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df6.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=Energy,palette='Blues')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (270,282))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df6.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.boxplot(y= 'values', x='attri' , hue= 'run', data=co2,palette='Blues')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (79,82))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
df7 = pd.read_csv('exp_bio2meth(biomethane).csv')

# %%
plt.figure(figsize=(10,5))
sns.set()
ax = sns.barplot(y= 'values', x='attri' , hue= 'run', data=df7,palette ='Greens')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='m3/ tonne')
ax.set(ylim = (3.8,4.5))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %% [markdown]
# Changing electricity conversion route to 'Biomethane to electricity'

# %%
df8 = pd.read_csv('exp_wms_meth2elec.csv')

# %%
cost_per_tonne= df8.iloc[1::4,:]
print (cost_per_tonne)
# Out:
#          values attri            run  Unnamed: 3                      route
# 1    119.366331  cost   240L, weekly         NaN  Biomethane to electricity
# 5    119.542092  cost   240L, weekly         NaN  Biomethane to electricity
# 9    118.910459  cost   240L, weekly         NaN  Biomethane to electricity
# 13   118.163135  cost   240L, weekly         NaN  Biomethane to electricity
# 17   119.887358  cost   240L, weekly         NaN  Biomethane to electricity
# ..          ...   ...            ...         ...                        ...
# 941  107.497099  cost  480L,biweekly         NaN      Biogas to electricity
# 945  107.650392  cost  480L,biweekly         NaN      Biogas to electricity
# 949  107.504421  cost  480L,biweekly         NaN      Biogas to electricity
# 953  108.366783  cost  480L,biweekly         NaN      Biogas to electricity
# 957  108.267418  cost  480L,biweekly         NaN      Biogas to electricity
#
# [240 rows x 5 columns]

# %%
cost_per_tonne= df8.iloc[1::4,:]
plt.figure(figsize=(10,5))
sns.set()
ax = sns.barplot(y= 'values', x='run' , hue='route', data=cost_per_tonne,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,130))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df8.iloc[2::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='run' , hue= 'route', data=Energy,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (250,310))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df8.iloc[3::4,:]
plt.figure(figsize=(10,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='run' , hue= 'route', data=co2,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (75,95))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
df9 = pd.read_csv('exp_behavior_meth2elec.csv')

# %%
cost_per_tonne= df9.iloc[1::4,:]
plt.figure(figsize=(14,5))
sns.set()
ax = sns.barplot(y= 'values', x='run' , hue='route', data=cost_per_tonne,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR/ tonne')
ax.set(ylim = (105,130))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
Energy= df9.iloc[2::4,:]
plt.figure(figsize=(14,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='run' , hue= 'route', data=Energy,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='KWh/ tonne')
ax.set(ylim = (250,310))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
co2= df9.iloc[3::4,:]
plt.figure(figsize=(14,5))
#sns.set(style="whitegrid")
ax = sns.barplot(y= 'values', x='run' , hue= 'route', data=co2,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='CO2 kg/tonne')
ax.set(ylim = (75,95))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')

# %%
dR = Energy["values"].div(Energy["values"])
#v = Energy.values / cost_per_tonne.values

# %%
print (Energy)
# Out:
#           values   attri              run                      route
# 2     289.879876  energy         Baseline  Biomethane to electricity
# 6     291.298350  energy         Baseline  Biomethane to electricity
# 10    290.603776  energy         Baseline  Biomethane to electricity
# 14    289.725289  energy         Baseline  Biomethane to electricity
# 18    291.463923  energy         Baseline  Biomethane to electricity
# ...          ...     ...              ...                        ...
# 1662  296.348874  energy  Highly egoistic      Biogas to electricity
# 1666  295.526630  energy  Highly egoistic      Biogas to electricity
# 1670  295.340877  energy  Highly egoistic      Biogas to electricity
# 1674  295.259881  energy  Highly egoistic      Biogas to electricity
# 1678  294.619190  energy  Highly egoistic      Biogas to electricity
#
# [420 rows x 4 columns]

# %%
dff= Energy.reset_index(drop=True)
print (dff)
dff2 = cost_per_tonne.reset_index(drop=True)
# Out:
#          values   attri              run                      route
# 0    289.879876  energy         Baseline  Biomethane to electricity
# 1    291.298350  energy         Baseline  Biomethane to electricity
# 2    290.603776  energy         Baseline  Biomethane to electricity
# 3    289.725289  energy         Baseline  Biomethane to electricity
# 4    291.463923  energy         Baseline  Biomethane to electricity
# ..          ...     ...              ...                        ...
# 415  296.348874  energy  Highly egoistic      Biogas to electricity
# 416  295.526630  energy  Highly egoistic      Biogas to electricity
# 417  295.340877  energy  Highly egoistic      Biogas to electricity
# 418  295.259881  energy  Highly egoistic      Biogas to electricity
# 419  294.619190  energy  Highly egoistic      Biogas to electricity
#
# [420 rows x 4 columns]

# %%
drr = dff['values'].div(dff2['values'], axis=0)
drr.to_csv( "output.csv", sep='\t',index= False)
# Out:
# D:\Python\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
Energy['values'].values / cost_per_tonne[['values']].values  # or df2.values assuming there's only 1 column
# 0.24+
Energy['values'].to_numpy() / Energy[['values']].to_numpy()
# Out:
# array([[1.        , 1.00489332, 1.00249724, ..., 1.01883884, 1.01855943,
#         1.01634924],
#        [0.99513051, 1.        , 0.99761559, ..., 1.01387762, 1.01359956,
#         1.01140013],
#        [0.99750898, 1.00239011, 1.        , ..., 1.01630089, 1.01602218,
#         1.01381749],
#        ...,
#        [0.9815095 , 0.98631234, 0.98396056, ..., 1.        , 0.99972575,
#         0.99755643],
#        [0.98177875, 0.9865829 , 0.98423048, ..., 1.00027432, 1.        ,
#         0.99783008],
#        [0.98391376, 0.98872837, 0.98637083, ..., 1.00244956, 1.00217464,
#         1.        ]])

# %%
df10 = pd.read_csv('output.csv')

# %%
plt.figure(figsize=(14,5))
sns.set()
ax = sns.barplot(y= 'values', x='run' , hue='route', data=df10,palette='GnBu')
ax.set(xlabel=' ')
ax.set(xlabel =' ',ylabel='EUR / KWh')
ax.set(ylim = (0.36,0.39))
ax.set_title(" ")
l = ax.legend()
l.set_title(' ')
